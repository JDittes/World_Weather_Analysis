# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_desc,
                          "Date": city_date})

# # If an error is experienced, skip the city.
    except:
         print("City not found. Skipping...")
         pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Error with weather description: IndentationError: unexpected unindent
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | lebu
# Processing Record 2 of Set 16 | caravelas
# Processing Record 3 of Set 16 | ancud
# Processing Record 4 of Set 16 | jamestown
# Processing Record 5 of Set 16 | puerto ayora
# Processing Record 6 of Set 16 | baruun-urt
# Processing Record 7 of Set 16 | tuktoyaktuk
# Processing Record 8 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 16 | saint petersburg
# Processing Record 10 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 16 | hilo
# Processing Record 12 of Set 16 | biak
# Processing Record 13 of Set 16 | torbay
# Processing Record 14 of Set 16 | dicabisagan
# Processing Record 15 of Set 16 | nome
# Processing Record 16 of Set 16 | pisco
# Processing Record 17 of Set 16 | rikitea
# Processing Record 18 of Set 16 | caconde
# Processing Record 19 of Set 16 | ribeira grande
# Processing Record 20 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 16 | san felipe
# Processing Record 22 of Set 16 | leningradskiy
# Processing Record 23 of Set 16 | senador canedo
# Processing Record 24 of Set 16 | busselton
# Processing Record 25 of Set 16 | east london
# Processing Record 26 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 16 | howard springs
# Processing Record 29 of Set 16 | port alfred
# Processing Record 30 of Set 16 | sioux lookout
# Processing Record 31 of Set 16 | bluff
# Processing Record 32 of Set 16 | hithadhoo
# Processing Record 33 of Set 16 | punta arenas
# Processing Record 34 of Set 16 | nova vicosa
# Processing Record 35 of Set 16 | yerbogachen
# Processing Record 36 of Set 16 | thompson
# Processing Record 37 of Set 16 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 16 | ixtapa
# Processing Record 39 of Set 16 | gloucester
# Processing Record 40 of Set 16 | bredasdorp
# Processing Record 41 of Set 16 | barrow
# Processing Record 42 of Set 16 | katsuura
# Processing Record 43 of Set 16 | fairview
# Processing Record 44 of Set 16 | hermanus
# Processing Record 45 of Set 16 | lauchhammer
# Processing Record 46 of Set 16 | otjimbingwe
# Processing Record 47 of Set 16 | ilulissat
# Processing Record 48 of Set 16 | naryan-mar
# Processing Record 49 of Set 16 | namatanai
# Processing Record 50 of Set 16 | arraial do cabo
# Processing Record 1 of Set 17 | lianzhou
# Processing Record 2 of Set 17 | georgetown
# Processing Record 3 of Set 17 | mecca
# Processing Record 4 of Set 17 | boyolangu
# Processing Record 5 of Set 17 | vaini
# Processing Record 6 of Set 17 | butaritari
# Processing Record 7 of Set 17 | klamath falls
# Processing Record 8 of Set 17 | sohag
# Processing Record 9 of Set 17 | manica
# Processing Record 10 of Set 17 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 17 | albany
# Processing Record 12 of Set 17 | kisangani
# Processing Record 13 of Set 17 | qaanaaq
# Processing Record 14 of Set 17 | troitsko-pechorsk
# Processing Record 15 of Set 17 | ushuaia
# Processing Record 16 of Set 17 | poum
# Processing Record 17 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 17 | tasiilaq
# Processing Record 19 of Set 17 | mar del plata
# Processing Record 20 of Set 17 | port moresby
# Processing Record 21 of Set 17 | yunjinghong
# City not found. Skipping...
# Processing Record 22 of Set 17 | dikson
# Processing Record 23 of Set 17 | naze
# Processing Record 24 of Set 17 | saskylakh
# Processing Record 25 of Set 17 | saint anthony
# Processing Record 26 of Set 17 | mwinilunga
# Processing Record 27 of Set 17 | khandyga
# Processing Record 28 of Set 17 | saint-augustin
# Processing Record 29 of Set 17 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 17 | tilichiki
# Processing Record 31 of Set 17 | bollnas
# Processing Record 32 of Set 17 | faanui
# Processing Record 33 of Set 17 | clyde river
# Processing Record 34 of Set 17 | banda aceh
# Processing Record 35 of Set 17 | taoudenni
# Processing Record 36 of Set 17 | codajas
# Processing Record 37 of Set 17 | mahebourg
# Processing Record 38 of Set 17 | avarua
# Processing Record 39 of Set 17 | nanortalik
# Processing Record 40 of Set 17 | gizo
# Processing Record 41 of Set 17 | kapaa
# Processing Record 42 of Set 17 | peterhead
# Processing Record 43 of Set 17 | sakakah
# Processing Record 44 of Set 17 | porto novo
# Processing Record 45 of Set 17 | ostrovnoy
# Processing Record 46 of Set 17 | berdigestyakh
# Processing Record 47 of Set 17 | punta gorda
# Processing Record 48 of Set 17 | bud
# Processing Record 49 of Set 17 | taihe
# Processing Record 50 of Set 17 | hamilton
# Processing Record 1 of Set 18 | san quintin
# Processing Record 2 of Set 18 | bethel
# Processing Record 3 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 18 | le vauclin
# Processing Record 5 of Set 18 | atuona
# Processing Record 6 of Set 18 | hofn
# Processing Record 7 of Set 18 | klaksvik
# Processing Record 8 of Set 18 | castro
# Processing Record 9 of Set 18 | chokurdakh
# Processing Record 10 of Set 18 | geraldton
# Processing Record 11 of Set 18 | faya
# Processing Record 12 of Set 18 | cabo san lucas
# Processing Record 13 of Set 18 | sao filipe
# Processing Record 14 of Set 18 | mamallapuram
# Processing Record 15 of Set 18 | constitucion
# Processing Record 16 of Set 18 | garowe
# Processing Record 17 of Set 18 | aanekoski
# Processing Record 18 of Set 18 | yeppoon
# Processing Record 19 of Set 18 | verkhnevilyuysk
# Processing Record 20 of Set 18 | vostok
# Processing Record 21 of Set 18 | xuddur
# Processing Record 22 of Set 18 | kabare
# Processing Record 23 of Set 18 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 18 | kavieng
# Processing Record 25 of Set 18 | springfield
# Processing Record 26 of Set 18 | cesvaine
# Processing Record 27 of Set 18 | carnarvon
# Processing Record 28 of Set 18 | sitka
# Processing Record 29 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 18 | ahuimanu
# Processing Record 31 of Set 18 | mehamn
# Processing Record 32 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 18 | mataura
# Processing Record 34 of Set 18 | maues
# Processing Record 35 of Set 18 | nagram
# Processing Record 36 of Set 18 | butka
# Processing Record 37 of Set 18 | sinnamary
# Processing Record 38 of Set 18 | tiznit
# Processing Record 39 of Set 18 | erzin
# Processing Record 40 of Set 18 | maneadero
# Processing Record 41 of Set 18 | airai
# Processing Record 42 of Set 18 | bandarbeyla
# Processing Record 43 of Set 18 | kattivakkam
# Processing Record 44 of Set 18 | hobart
# Processing Record 45 of Set 18 | noshiro
# Processing Record 46 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 18 | port hardy
# Processing Record 48 of Set 18 | harper
# Processing Record 49 of Set 18 | khani
# Processing Record 50 of Set 18 | monte alegre de minas
# Processing Record 1 of Set 19 | ptichye
# Processing Record 2 of Set 19 | salalah
# Processing Record 3 of Set 19 | yulara
# Processing Record 4 of Set 19 | tabuk
# Processing Record 5 of Set 19 | luderitz
# Processing Record 6 of Set 19 | kodiak
# Processing Record 7 of Set 19 | balabac
# Processing Record 8 of Set 19 | kangalassy
# Processing Record 9 of Set 19 | esperance
# Processing Record 10 of Set 19 | kamina
# Processing Record 11 of Set 19 | saint-philippe
# Processing Record 12 of Set 19 | honiara
# Processing Record 13 of Set 19 | kualakapuas
# Processing Record 14 of Set 19 | tabou
# Processing Record 15 of Set 19 | lagoa
# Processing Record 16 of Set 19 | pacific grove
# Processing Record 17 of Set 19 | kahului
# Processing Record 18 of Set 19 | victoria
# Processing Record 19 of Set 19 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 19 | surovikino
# Processing Record 21 of Set 19 | gediz
# Processing Record 22 of Set 19 | bugene
# Processing Record 23 of Set 19 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 19 | vestmannaeyjar
# Processing Record 25 of Set 19 | lichinga
# Processing Record 26 of Set 19 | roald
# Processing Record 27 of Set 19 | mwense
# Processing Record 28 of Set 19 | jieshi
# Processing Record 29 of Set 19 | raver
# Processing Record 30 of Set 19 | yellowknife
# Processing Record 31 of Set 19 | mitsamiouli
# Processing Record 32 of Set 19 | neryungri
# Processing Record 33 of Set 19 | kulhudhuffushi
# Processing Record 34 of Set 19 | vardo
# Processing Record 35 of Set 19 | villaviciosa
# Processing Record 36 of Set 19 | eganville
# Processing Record 37 of Set 19 | port hueneme
# Processing Record 38 of Set 19 | upernavik
# Processing Record 39 of Set 19 | ereymentau
# Processing Record 40 of Set 19 | boende
# Processing Record 41 of Set 19 | bengkulu
# Processing Record 42 of Set 19 | kabala
# Processing Record 43 of Set 19 | erenhot
# Processing Record 44 of Set 19 | mukhen
# Processing Record 45 of Set 19 | nishihara
# Processing Record 46 of Set 19 | cidreira
# Processing Record 47 of Set 19 | morondava
# Processing Record 48 of Set 19 | talnakh
# Processing Record 49 of Set 19 | mgandu
# Processing Record 50 of Set 19 | jega
# Processing Record 1 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 20 | khatanga
# Processing Record 4 of Set 20 | bambous virieux
# Processing Record 5 of Set 20 | oktyabrskiy
# Processing Record 6 of Set 20 | nouadhibou
# Processing Record 7 of Set 20 | coihaique
# Processing Record 8 of Set 20 | cap malheureux
# Processing Record 9 of Set 20 | itoman
# Processing Record 10 of Set 20 | stokmarknes
# Processing Record 11 of Set 20 | ponta do sol
# Processing Record 12 of Set 20 | mackay
# Processing Record 13 of Set 20 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 20 | port lincoln
# Processing Record 15 of Set 20 | iqaluit
# Processing Record 16 of Set 20 | verkhoyansk
# Processing Record 17 of Set 20 | bloemfontein
# Processing Record 18 of Set 20 | port shepstone
# Processing Record 19 of Set 20 | port elizabeth
# Processing Record 20 of Set 20 | pangnirtung
# Processing Record 21 of Set 20 | rafaela
# Processing Record 22 of Set 20 | shaunavon
# Processing Record 23 of Set 20 | salvador
# Processing Record 24 of Set 20 | praia
# Processing Record 25 of Set 20 | nikolskoye
# Processing Record 26 of Set 20 | lavrentiya
# Processing Record 27 of Set 20 | beidao
# Processing Record 28 of Set 20 | stawell
# Processing Record 29 of Set 20 | cape town
# Processing Record 30 of Set 20 | la ronge
# Processing Record 31 of Set 20 | zhongshan
# Processing Record 32 of Set 20 | labuhan
# Processing Record 33 of Set 20 | hurricane
# Processing Record 34 of Set 20 | kushima
# Processing Record 35 of Set 20 | havre-saint-pierre
# Processing Record 36 of Set 20 | dakar
# Processing Record 37 of Set 20 | fortuna
# Processing Record 38 of Set 20 | roma
# Processing Record 39 of Set 20 | atar
# Processing Record 40 of Set 20 | salym
# Processing Record 41 of Set 20 | pangkalanbuun
# Processing Record 42 of Set 20 | pemangkat
# Processing Record 43 of Set 20 | seoul
# Processing Record 44 of Set 20 | saint george
# Processing Record 45 of Set 20 | amudat
# Processing Record 46 of Set 20 | vilyuysk
# Processing Record 47 of Set 20 | cherskiy
# Processing Record 48 of Set 20 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 20 | atlantic city
# Processing Record 50 of Set 20 | sumbe
# Processing Record 1 of Set 21 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 21 | agaro
# Processing Record 3 of Set 21 | nemuro
# Processing Record 4 of Set 21 | husavik
# Processing Record 5 of Set 21 | gornopravdinsk
# Processing Record 6 of Set 21 | perry hall
# Processing Record 7 of Set 21 | kingaroy
# Processing Record 8 of Set 21 | aksarka
# Processing Record 9 of Set 21 | san ramon
# Processing Record 10 of Set 21 | kashira
# Processing Record 11 of Set 21 | iquique
# Processing Record 12 of Set 21 | jacareacanga
# Processing Record 13 of Set 21 | tiksi
# Processing Record 14 of Set 21 | bintulu
# Processing Record 15 of Set 21 | bardiyah
# Processing Record 16 of Set 21 | olga
# Processing Record 17 of Set 21 | springbok
# Processing Record 18 of Set 21 | vangaindrano
# Processing Record 19 of Set 21 | hobyo
# Processing Record 20 of Set 21 | grand gaube
# Processing Record 21 of Set 21 | port-gentil
# Processing Record 22 of Set 21 | abengourou
# Processing Record 23 of Set 21 | auki
# Processing Record 24 of Set 21 | rocha
# Processing Record 25 of Set 21 | kabanjahe
# Processing Record 26 of Set 21 | emerald
# Processing Record 27 of Set 21 | hvide sande
# Processing Record 28 of Set 21 | miquelon
# Processing Record 29 of Set 21 | zhangjiakou
# Processing Record 30 of Set 21 | sai buri
# Processing Record 31 of Set 21 | port blair
# Processing Record 32 of Set 21 | makakilo city
# Processing Record 33 of Set 21 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 21 | ishigaki
# Processing Record 35 of Set 21 | pak thong chai
# Processing Record 36 of Set 21 | reconquista
# Processing Record 37 of Set 21 | port hedland
# Processing Record 38 of Set 21 | gamba
# Processing Record 39 of Set 21 | yar-sale
# Processing Record 40 of Set 21 | portland
# Processing Record 41 of Set 21 | mount gambier
# Processing Record 42 of Set 21 | camacha
# Processing Record 43 of Set 21 | hasaki
# Processing Record 44 of Set 21 | micomeseng
# Processing Record 45 of Set 21 | dingle
# Processing Record 46 of Set 21 | gat
# Processing Record 47 of Set 21 | solnechnyy
# Processing Record 48 of Set 21 | lompoc
# Processing Record 49 of Set 21 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 21 | knysna
# Processing Record 1 of Set 22 | azad shahr
# Processing Record 2 of Set 22 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 22 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 22 | severobaykalsk
# Processing Record 5 of Set 22 | havoysund
# Processing Record 6 of Set 22 | sovetskiy
# Processing Record 7 of Set 22 | vuktyl
# Processing Record 8 of Set 22 | gharo
# Processing Record 9 of Set 22 | new norfolk
# Processing Record 10 of Set 22 | aasiaat
# Processing Record 11 of Set 22 | beringovskiy
# Processing Record 12 of Set 22 | saint-michel-des-saints
# Processing Record 13 of Set 22 | erzincan
# Processing Record 14 of Set 22 | sortavala
# Processing Record 15 of Set 22 | mount isa
# Processing Record 16 of Set 22 | muravlenko
# Processing Record 17 of Set 22 | ust-maya
# Processing Record 18 of Set 22 | progreso
# Processing Record 19 of Set 22 | isabela
# Processing Record 20 of Set 22 | ishnya
# Processing Record 21 of Set 22 | great yarmouth
# Processing Record 22 of Set 22 | mooi river
# City not found. Skipping...
# Processing Record 23 of Set 22 | berlevag
# Processing Record 24 of Set 22 | jidong
# Processing Record 25 of Set 22 | tuatapere
# Processing Record 26 of Set 22 | siocon
# Processing Record 27 of Set 22 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 22 | jales
# Processing Record 29 of Set 22 | burnie
# Processing Record 30 of Set 22 | san patricio
# Processing Record 31 of Set 22 | sisimiut
# Processing Record 32 of Set 22 | south houston
# Processing Record 33 of Set 22 | tanabi
# Processing Record 34 of Set 22 | marystown
# Processing Record 35 of Set 22 | buraydah
# Processing Record 36 of Set 22 | gidam
# Processing Record 37 of Set 22 | george town
# Processing Record 38 of Set 22 | oinoussai
# City not found. Skipping...
# Processing Record 39 of Set 22 | san cristobal
# Processing Record 40 of Set 22 | coalinga
# Processing Record 41 of Set 22 | ye
# City not found. Skipping...
# Processing Record 42 of Set 22 | oga
# Processing Record 43 of Set 22 | tsiroanomandidy
# Processing Record 44 of Set 22 | buala
# Processing Record 45 of Set 22 | bonthe
# Processing Record 46 of Set 22 | yumen
# Processing Record 47 of Set 22 | pontianak
# Processing Record 48 of Set 22 | tadine
# Processing Record 49 of Set 22 | olinda
# Processing Record 50 of Set 22 | traverse city
# Processing Record 1 of Set 23 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 23 | muros
# Processing Record 3 of Set 23 | aranos
# Processing Record 4 of Set 23 | broken hill
# Processing Record 5 of Set 23 | aklavik
# Processing Record 6 of Set 23 | souillac
# Processing Record 7 of Set 23 | lucapa
# Processing Record 8 of Set 23 | banswara
# Processing Record 9 of Set 23 | alofi
# Processing Record 10 of Set 23 | bonavista
# Processing Record 11 of Set 23 | vodnyy
# Processing Record 12 of Set 23 | kupino
# Processing Record 13 of Set 23 | boca do acre
# Processing Record 14 of Set 23 | sorvag
# City not found. Skipping...
# Processing Record 15 of Set 23 | college
# Processing Record 16 of Set 23 | shingu
# Processing Record 17 of Set 23 | gravdal
# Processing Record 18 of Set 23 | lasa
# Processing Record 19 of Set 23 | katobu
# Processing Record 20 of Set 23 | maracacume
# Processing Record 21 of Set 23 | necochea
# Processing Record 22 of Set 23 | kaitangata
# Processing Record 23 of Set 23 | pilcaya
# Processing Record 24 of Set 23 | santa maria da boa vista
# Processing Record 25 of Set 23 | sabang
# Processing Record 26 of Set 23 | bastia
# Processing Record 27 of Set 23 | griffith
# Processing Record 28 of Set 23 | muisne
# Processing Record 29 of Set 23 | port augusta
# Processing Record 30 of Set 23 | znamenskoye
# Processing Record 31 of Set 23 | pevek
# Processing Record 32 of Set 23 | anadyr
# Processing Record 33 of Set 23 | skjervoy
# Processing Record 34 of Set 23 | banepa
# Processing Record 35 of Set 23 | santa maria
# Processing Record 36 of Set 23 | ramshir
# Processing Record 37 of Set 23 | norman wells
# Processing Record 38 of Set 23 | port washington
# Processing Record 39 of Set 23 | karratha
# Processing Record 40 of Set 23 | mumford
# Processing Record 41 of Set 23 | tawnat
# City not found. Skipping...
# Processing Record 42 of Set 23 | aswan
# Processing Record 43 of Set 23 | taltal
# Processing Record 44 of Set 23 | tyret pervaya
# Processing Record 45 of Set 23 | salinas
# Processing Record 46 of Set 23 | sembakung
# Processing Record 47 of Set 23 | teofilo otoni
# Processing Record 48 of Set 23 | praskoveya
# Processing Record 49 of Set 23 | yomitan
# City not found. Skipping...
# Processing Record 50 of Set 23 | berberati
# Processing Record 1 of Set 24 | chitipa
# Processing Record 2 of Set 24 | victoria point
# Processing Record 3 of Set 24 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 24 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 24 | orange walk
# Processing Record 6 of Set 24 | srednekolymsk
# Processing Record 7 of Set 24 | mission
# Processing Record 8 of Set 24 | moron
# Processing Record 9 of Set 24 | vanavara
# Processing Record 10 of Set 24 | muromtsevo
# Processing Record 11 of Set 24 | avera
# Processing Record 12 of Set 24 | graaff-reinet
# Processing Record 13 of Set 24 | bengkalis
# City not found. Skipping...
# Processing Record 14 of Set 24 | crestline
# Processing Record 15 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 24 | sept-iles
# Processing Record 17 of Set 24 | carballo
# Processing Record 18 of Set 24 | adrar
# Processing Record 19 of Set 24 | toora-khem
# Processing Record 20 of Set 24 | trelew
# Processing Record 21 of Set 24 | brae
# Processing Record 22 of Set 24 | shibarghan
# City not found. Skipping...
# Processing Record 23 of Set 24 | nantucket
# Processing Record 24 of Set 24 | arman
# Processing Record 25 of Set 24 | jumla
# Processing Record 26 of Set 24 | chuy
# Processing Record 27 of Set 24 | seminole
# Processing Record 28 of Set 24 | chifeng
# Processing Record 29 of Set 24 | beloha
# Processing Record 30 of Set 24 | hambantota
# Processing Record 31 of Set 24 | hualmay
# Processing Record 32 of Set 24 | touros
# Processing Record 33 of Set 24 | nabire
# Processing Record 34 of Set 24 | kenai
# Processing Record 35 of Set 24 | krasnoselkup
# Processing Record 36 of Set 24 | spencer
# Processing Record 37 of Set 24 | flin flon
# Processing Record 38 of Set 24 | kununurra
# Processing Record 39 of Set 24 | anloga
# Processing Record 40 of Set 24 | wa
# City not found. Skipping...
# Processing Record 41 of Set 24 | north bend
# Processing Record 42 of Set 24 | porsa
# Processing Record 43 of Set 24 | zhuhai
# Processing Record 44 of Set 24 | dobryanka
# Processing Record 45 of Set 24 | moroto
# Processing Record 46 of Set 24 | teguise
# Processing Record 47 of Set 24 | chagda
# City not found. Skipping...
# Processing Record 48 of Set 24 | batticaloa
# Processing Record 49 of Set 24 | aykhal
# Processing Record 50 of Set 24 | zahesi
# Processing Record 1 of Set 25 | silver city
# Processing Record 2 of Set 25 | puerto escondido
# Processing Record 3 of Set 25 | sasebo
# Processing Record 4 of Set 25 | bayan
# Processing Record 5 of Set 25 | san carlos
# Processing Record 6 of Set 25 | aquiraz
# Processing Record 7 of Set 25 | boa vista
# Processing Record 8 of Set 25 | barentu
# Processing Record 9 of Set 25 | jaisinghnagar
# Processing Record 10 of Set 25 | kabalo
# Processing Record 11 of Set 25 | nicoya
# Processing Record 12 of Set 25 | the pas
# Processing Record 13 of Set 25 | mongu
# Processing Record 14 of Set 25 | manta
# Processing Record 15 of Set 25 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 25 | saldanha
# Processing Record 17 of Set 25 | kieta
# Processing Record 18 of Set 25 | bani
# Processing Record 19 of Set 25 | chilca
# Processing Record 20 of Set 25 | skjern
# Processing Record 21 of Set 25 | svetlyy
# Processing Record 22 of Set 25 | nioro
# Processing Record 23 of Set 25 | vilhena
# Processing Record 24 of Set 25 | kloulklubed
# Processing Record 25 of Set 25 | acajutla
# Processing Record 26 of Set 25 | urumqi
# Processing Record 27 of Set 25 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 25 | asayita
# City not found. Skipping...
# Processing Record 29 of Set 25 | yenagoa
# Processing Record 30 of Set 25 | andenes
# Processing Record 31 of Set 25 | tucuma
# Processing Record 32 of Set 25 | sultanpur
# Processing Record 33 of Set 25 | paamiut
# Processing Record 34 of Set 25 | saint-joseph
# Processing Record 35 of Set 25 | luwuk
# Processing Record 36 of Set 25 | zaraza
# Processing Record 37 of Set 25 | santa cruz
# Processing Record 38 of Set 25 | ploemeur
# Processing Record 39 of Set 25 | saraland
# Processing Record 40 of Set 25 | badiraguato
# Processing Record 41 of Set 25 | rumonge
# Processing Record 42 of Set 25 | siparia
# Processing Record 43 of Set 25 | faxinal
# Processing Record 44 of Set 25 | hay river
# Processing Record 45 of Set 25 | houston
# Processing Record 46 of Set 25 | lar gerd
# City not found. Skipping...
# Processing Record 47 of Set 25 | akyab
# Processing Record 48 of Set 25 | tandalti
# Processing Record 49 of Set 25 | mackenzie
# Processing Record 50 of Set 25 | comrat
# Processing Record 1 of Set 26 | shelburne
# Processing Record 2 of Set 26 | butterworth
# Processing Record 3 of Set 26 | paragominas
# Processing Record 4 of Set 26 | lashio
# Processing Record 5 of Set 26 | maniitsoq
# Processing Record 6 of Set 26 | amarante do maranhao
# Processing Record 7 of Set 26 | najran
# Processing Record 8 of Set 26 | aleksandrov gay
# Processing Record 9 of Set 26 | vanimo
# Processing Record 10 of Set 26 | batagay-alyta
# Processing Record 11 of Set 26 | swift current
# Processing Record 12 of Set 26 | conde
# Processing Record 13 of Set 26 | landeck
# Processing Record 14 of Set 26 | sangueya
# Processing Record 15 of Set 26 | bowen
# Processing Record 16 of Set 26 | alice springs
# Processing Record 17 of Set 26 | crestview
# Processing Record 18 of Set 26 | orichi
# Processing Record 19 of Set 26 | slave lake
# Processing Record 20 of Set 26 | la sarre
# Processing Record 21 of Set 26 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 26 | chiredzi
# Processing Record 23 of Set 26 | kavaratti
# Processing Record 24 of Set 26 | saint-pierre
# Processing Record 25 of Set 26 | asekeyevo
# Processing Record 26 of Set 26 | quatre cocos
# Processing Record 27 of Set 26 | kiruna
# Processing Record 28 of Set 26 | villa maria
# Processing Record 29 of Set 26 | san jeronimo
# Processing Record 30 of Set 26 | arlit
# Processing Record 31 of Set 26 | tooele
# Processing Record 32 of Set 26 | churapcha
# Processing Record 33 of Set 26 | vila velha
# Processing Record 34 of Set 26 | huron
# Processing Record 35 of Set 26 | sri aman
# Processing Record 36 of Set 26 | marsh harbour
# Processing Record 37 of Set 26 | moree
# Processing Record 38 of Set 26 | kutum
# Processing Record 39 of Set 26 | cayenne
# Processing Record 40 of Set 26 | medicine hat
# Processing Record 41 of Set 26 | okhotsk
# Processing Record 42 of Set 26 | sambava
# Processing Record 43 of Set 26 | lazaro cardenas
# Processing Record 44 of Set 26 | gushikawa
# Processing Record 45 of Set 26 | yichang
# Processing Record 46 of Set 26 | laguna
# Processing Record 47 of Set 26 | saint-francois
# Processing Record 48 of Set 26 | pingyin
# Processing Record 49 of Set 26 | agadir
# Processing Record 50 of Set 26 | safaqis
# City not found. Skipping...
# Processing Record 1 of Set 27 | celestun
# Processing Record 2 of Set 27 | tacuati
# Processing Record 3 of Set 27 | port macquarie
# Processing Record 4 of Set 27 | nekhayevskiy
# Processing Record 5 of Set 27 | cockburn harbour
# City not found. Skipping...
# Processing Record 6 of Set 27 | beisfjord
# Processing Record 7 of Set 27 | novyy urgal
# Processing Record 8 of Set 27 | morinville
# Processing Record 9 of Set 27 | meulaboh
# Processing Record 10 of Set 27 | ulaangom
# Processing Record 11 of Set 27 | comodoro rivadavia
# Processing Record 12 of Set 27 | finschhafen
# Processing Record 13 of Set 27 | maghar
# Processing Record 14 of Set 27 | maridi
# Processing Record 15 of Set 27 | edgewater
# Processing Record 16 of Set 27 | codrington
# Processing Record 17 of Set 27 | mago
# Processing Record 18 of Set 27 | eskil
# Processing Record 19 of Set 27 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 27 | kirakira
# Processing Record 21 of Set 27 | maneromango
# Processing Record 22 of Set 27 | tateyama
# Processing Record 23 of Set 27 | deputatskiy
# Processing Record 24 of Set 27 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 27 | hailar
# Processing Record 26 of Set 27 | ketchikan
# Processing Record 27 of Set 27 | paidha
# Processing Record 28 of Set 27 | kon tum
# Processing Record 29 of Set 27 | tonk
# Processing Record 30 of Set 27 | miyako
# Processing Record 31 of Set 27 | orlik
# Processing Record 32 of Set 27 | saurimo
# Processing Record 33 of Set 27 | ulladulla
# Processing Record 34 of Set 27 | anchorage
# Processing Record 35 of Set 27 | coolum beach
# Processing Record 36 of Set 27 | manalurpet
# City not found. Skipping...
# Processing Record 37 of Set 27 | broome
# Processing Record 38 of Set 27 | khromtau
# Processing Record 39 of Set 27 | piracuruca
# Processing Record 40 of Set 27 | auce
# Processing Record 41 of Set 27 | eskisehir
# Processing Record 42 of Set 27 | khudumelapye
# Processing Record 43 of Set 27 | egvekinot
# Processing Record 44 of Set 27 | serpneve
# Processing Record 45 of Set 27 | aransas pass
# Processing Record 46 of Set 27 | lebedyn
# Processing Record 47 of Set 27 | micheweni
# Processing Record 48 of Set 27 | seeboden
# Processing Record 49 of Set 27 | westport
# Processing Record 50 of Set 27 | betare oya
# Processing Record 1 of Set 28 | umba
# Processing Record 2 of Set 28 | gimbi
# Processing Record 3 of Set 28 | murray bridge
# Processing Record 4 of Set 28 | kaniama
# Processing Record 5 of Set 28 | prince rupert
# Processing Record 6 of Set 28 | riyadh
# Processing Record 7 of Set 28 | pingliang
# Processing Record 8 of Set 28 | cavan
# Processing Record 9 of Set 28 | gutersloh
# Processing Record 10 of Set 28 | changji
# Processing Record 11 of Set 28 | petukhovo
# Processing Record 12 of Set 28 | tongliao
# Processing Record 13 of Set 28 | soja
# Processing Record 14 of Set 28 | lewistown
# Processing Record 15 of Set 28 | soe
# Processing Record 16 of Set 28 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 28 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 28 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 28 | juneau
# Processing Record 20 of Set 28 | kruisfontein
# Processing Record 21 of Set 28 | provideniya
# Processing Record 22 of Set 28 | port arthur
# Processing Record 23 of Set 28 | princeton
# Processing Record 24 of Set 28 | fairbanks
# Processing Record 25 of Set 28 | oksfjord
# Processing Record 26 of Set 28 | zheleznodorozhnyy
# Processing Record 27 of Set 28 | thinadhoo
# Processing Record 28 of Set 28 | vasteras
# Processing Record 29 of Set 28 | raga
# Processing Record 30 of Set 28 | coquimbo
# Processing Record 31 of Set 28 | bima
# Processing Record 32 of Set 28 | piazza armerina
# Processing Record 33 of Set 28 | jalu
# Processing Record 34 of Set 28 | inirida
# Processing Record 35 of Set 28 | bilma
# Processing Record 36 of Set 28 | drinovci
# Processing Record 37 of Set 28 | jiroft
# City not found. Skipping...
# Processing Record 38 of Set 28 | altamont
# Processing Record 39 of Set 28 | tres lagoas
# Processing Record 40 of Set 28 | mabaruma
# Processing Record 41 of Set 28 | rio grande
# Processing Record 42 of Set 28 | amahai
# Processing Record 43 of Set 28 | trinidad
# Processing Record 44 of Set 28 | tromso
# Processing Record 45 of Set 28 | caxito
# Processing Record 46 of Set 28 | praya
# Processing Record 47 of Set 28 | koulikoro
# Processing Record 48 of Set 28 | liverpool
# Processing Record 49 of Set 28 | trindade
# Processing Record 50 of Set 28 | joshimath
# Processing Record 1 of Set 29 | mizan teferi
# Processing Record 2 of Set 29 | sarakhs
# Processing Record 3 of Set 29 | tuy hoa
# Processing Record 4 of Set 29 | manono
# Processing Record 5 of Set 29 | san juan
# Processing Record 6 of Set 29 | sawtell
# Processing Record 7 of Set 29 | cockburn town
# Processing Record 8 of Set 29 | pangai
# Processing Record 9 of Set 29 | lillooet
# Processing Record 10 of Set 29 | kyabe
# Processing Record 11 of Set 29 | vao
# Processing Record 12 of Set 29 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 29 | kijang
# Processing Record 14 of Set 29 | waterboro
# Processing Record 15 of Set 29 | lesnikovo
# Processing Record 16 of Set 29 | asau
# Processing Record 17 of Set 29 | suicheng
# Processing Record 18 of Set 29 | gisborne
# Processing Record 19 of Set 29 | te anau
# Processing Record 20 of Set 29 | pandamatenga
# Processing Record 21 of Set 29 | tipperary
# Processing Record 22 of Set 29 | leh
# Processing Record 23 of Set 29 | kondol
# Processing Record 24 of Set 29 | anori
# Processing Record 25 of Set 29 | rio gallegos
# Processing Record 26 of Set 29 | kroya
# Processing Record 27 of Set 29 | isangel
# Processing Record 28 of Set 29 | maragogi
# Processing Record 29 of Set 29 | kaeo
# Processing Record 30 of Set 29 | palu
# Processing Record 31 of Set 29 | olean
# Processing Record 32 of Set 29 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 29 | nhamunda
# Processing Record 34 of Set 29 | north platte
# Processing Record 35 of Set 29 | bocana de paiwas
# Processing Record 36 of Set 29 | makung
# City not found. Skipping...
# Processing Record 37 of Set 29 | russell
# Processing Record 38 of Set 29 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 29 | lorengau
# Processing Record 40 of Set 29 | kaupanger
# Processing Record 41 of Set 29 | antalaha
# Processing Record 42 of Set 29 | pringsewu
# Processing Record 43 of Set 29 | chimore
# Processing Record 44 of Set 29 | new castle
# Processing Record 45 of Set 29 | malangwa
# Processing Record 46 of Set 29 | arys
# Processing Record 47 of Set 29 | itarema
# Processing Record 48 of Set 29 | noumea
# Processing Record 49 of Set 29 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 29 | geresk
# City not found. Skipping...
# Processing Record 1 of Set 30 | sao joao da barra
# Processing Record 2 of Set 30 | nizwa
# Processing Record 3 of Set 30 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 30 | los llanos de aridane
# Processing Record 5 of Set 30 | biltine
# Processing Record 6 of Set 30 | arari
# Processing Record 7 of Set 30 | chimoio
# Processing Record 8 of Set 30 | lanzhou
# Processing Record 9 of Set 30 | opoczno
# Processing Record 10 of Set 30 | areosa
# Processing Record 11 of Set 30 | ridgecrest
# Processing Record 12 of Set 30 | niquero
# Processing Record 13 of Set 30 | panzhihua
# Processing Record 14 of Set 30 | valparaiso
# Processing Record 15 of Set 30 | varhaug
# Processing Record 16 of Set 30 | imbituba
# Processing Record 17 of Set 30 | praia da vitoria
# Processing Record 18 of Set 30 | zyryanka
# Processing Record 19 of Set 30 | zharkent
# Processing Record 20 of Set 30 | kuusamo
# Processing Record 21 of Set 30 | maldonado
# Processing Record 22 of Set 30 | guiratinga
# Processing Record 23 of Set 30 | carutapera
# Processing Record 24 of Set 30 | colorado springs
# Processing Record 25 of Set 30 | ibra
# Processing Record 26 of Set 30 | talara
# Processing Record 27 of Set 30 | tir pol
# City not found. Skipping...
# Processing Record 28 of Set 30 | nadvoitsy
# Processing Record 29 of Set 30 | oda
# Processing Record 30 of Set 30 | hindoria
# Processing Record 31 of Set 30 | ternate
# Processing Record 32 of Set 30 | harlingen
# Processing Record 33 of Set 30 | peniche
# Processing Record 34 of Set 30 | garmsar
# Processing Record 35 of Set 30 | araouane
# Processing Record 36 of Set 30 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 30 | kuryk
# Processing Record 38 of Set 30 | namie
# Processing Record 39 of Set 30 | chumikan
# Processing Record 40 of Set 30 | mogadishu
# Processing Record 41 of Set 30 | carrickfergus
# Processing Record 42 of Set 30 | pakxe
# Processing Record 43 of Set 30 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 30 | marawi
# Processing Record 45 of Set 30 | madikeri
# Processing Record 46 of Set 30 | dalbandin
# Processing Record 47 of Set 30 | maputo
# Processing Record 48 of Set 30 | port-cartier
# Processing Record 49 of Set 30 | sao felix do xingu
# Processing Record 50 of Set 30 | katherine
# Processing Record 1 of Set 31 | pierre
# Processing Record 2 of Set 31 | zemio
# Processing Record 3 of Set 31 | severo-kurilsk
# Processing Record 4 of Set 31 | dinhata
# Processing Record 5 of Set 31 | waingapu
# Processing Record 6 of Set 31 | malaya vishera
# Processing Record 7 of Set 31 | aripuana
# Processing Record 8 of Set 31 | ewa beach
# Processing Record 9 of Set 31 | halifax
# Processing Record 10 of Set 31 | melfi
# Processing Record 11 of Set 31 | iskateley
# Processing Record 12 of Set 31 | pocone
# Processing Record 13 of Set 31 | nago
# Processing Record 14 of Set 31 | myitkyina
# Processing Record 15 of Set 31 | haines junction
# Processing Record 16 of Set 31 | puerto carreno
# Processing Record 17 of Set 31 | mukhtolovo
# Processing Record 18 of Set 31 | zhezkazgan
# Processing Record 19 of Set 31 | rjukan
# Processing Record 20 of Set 31 | tianpeng
# Processing Record 21 of Set 31 | pontes e lacerda
# Processing Record 22 of Set 31 | higuey
# City not found. Skipping...
# Processing Record 23 of Set 31 | ust-nera
# Processing Record 24 of Set 31 | norre aaby
# City not found. Skipping...
# Processing Record 25 of Set 31 | ozernovskiy
# Processing Record 26 of Set 31 | baie-comeau
# Processing Record 27 of Set 31 | labytnangi
# Processing Record 28 of Set 31 | kosonsoy
# Processing Record 29 of Set 31 | lusambo
# Processing Record 30 of Set 31 | lysva
# Processing Record 31 of Set 31 | atasu
# Processing Record 32 of Set 31 | prieska
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 715

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Lebu -37.6167  -73.6500     62.33        67          28
# 1         Caravelas -17.7125  -39.2481     82.76        65          14
# 2             Ancud -41.8697  -73.8203     62.13        70          67
# 3         Jamestown  42.0970  -79.2353     23.09        34           0
# 4      Puerto Ayora  -0.7393  -90.3518     80.56        75          85
# 5        Baruun-Urt  46.6806  113.2792     -1.89        98         100
# 6       Tuktoyaktuk  69.4541 -133.0374    -13.00        77          40
# 7  Saint Petersburg  59.8944   30.2642     21.34        86          75
# 8              Hilo  19.7297 -155.0900     74.62        75           0
# 9              Biak  -0.9131  122.8766     75.27        84          61
#
#    Wind Speed Country Weather Description                 Date
# 0        8.50      CL    scattered clouds  2022-01-22 18:42:03
# 1        9.33      BR          few clouds  2022-01-22 18:42:03
# 2       16.91      CL          light rain  2022-01-22 18:42:03
# 3        7.00      US           clear sky  2022-01-22 18:39:47
# 4        7.90      EC     overcast clouds  2022-01-22 18:42:04
# 5        3.51      MN     overcast clouds  2022-01-22 18:42:04
# 6       21.85      CA    scattered clouds  2022-01-22 18:42:04
# 7        6.71      RU       broken clouds  2022-01-22 18:39:52
# 8        1.99      US           clear sky  2022-01-22 18:39:10
# 9        3.65      ID       broken clouds  2022-01-22 18:42:05

# %%
city_data_df.to_csv('WeatherPy_Database.csv', index=False)
